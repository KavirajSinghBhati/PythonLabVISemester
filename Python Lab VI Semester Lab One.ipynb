# %% [markdown]
# # Lab One
#
# ## Objectives
#
# - What is Python and it's applications along with it's future.
# - Explain Numpy, Pandas, and Matplotlib
# - Basic Python Programs
#
# - Assignment 1: Perform basic arithmetic operations, swap two variables and find whether the given number is even or odd.

# %% [markdown]
# ### What is Python?
# Python is a high-level, interpreted, object-oriented programming language with dynamic semantics.  Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed.

# %% [markdown]
# ### Numpy
# Numpy is a library for Python which adds support for large, multidimensional arrays and matrices, along with a large number of mathematical functions to operate on them.
#
# ### Pandas
# Pandas is a library for Python which is used for working with datasets. It has functions for analysing, cleaning, exploring, and manipulating data.
#
# ### Matplotlib
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.

# %%
# How to print something?
print("Hello World")
# Out:
# Hello World

# %%
# How to take an integer input?
num1 = int(input("Enter a number: "))
# Out:
# Enter a number: 10

# %%
print(num1)
# Out:
# 10

# %%
# basic mathematical operations
print(10 + 2)
print(10 - 3)
print(10 * 4)
print(10 / 2)
print(10 % 3)  # modulo operation
print(20 ** 3) # 20 ^ 3
# Out:
# 12
# 7
# 40
# 5.0
# 1
# 8000

# %% [markdown]
# ## Program 1: Write a program in Python to swap two numbers.

# %%
a = int(input("Pl. enter the first number: "))
b = int(input("Pl. enter the second number: "))

print("Before swapping, a =", a, ", b =", b)

temp = a
a = b
b = temp

print("After swapping, a =", a, ", b =", b)
# Out:
# Pl. enter the first number: 12
# Pl. enter the second number: 43
# Before swapping, a = 12 , b = 43
# After swapping, a = 43 , b = 12

# %% [markdown]
# ## Program 2: Write a program in Python to find whether the given number is even or odd.

# %%
num = int(input("Enter the number to check for Even - Odd: "))
if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# Enter the number to check for Even - Odd: 12
# 12 is even

# %%
num = int(input("Enter the number to check for Even - Odd: "))
if num % 2 == 0:
    print(num, "is even")
else:
    print(num, "is odd")
# Out:
# Enter the number to check for Even - Odd: 19
# 19 is odd
